# %% [markdown]
# # Importing basic libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing DataSet

# %%
data = pd.read_csv("/content/Learner_marks_record.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-5d4e2c0c778d> in <module>
# ----> 1 data = pd.read_csv("/content/Learner_marks_record.csv")
#       2 data.head()
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data.isnull().sum()

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()

# %%
dataset1 = sorted(data, reverse = False)
print(dataset1)

# %% [markdown]
# # Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %%
X=data[["Hours_to_study"]]
X

# %%
y=data["Obtained_Marks"]
y

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25, random_state = 42 )

# %% [markdown]
# # ML

# %% [markdown]
# ## linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)

# %%
y_pred=lr.predict(X_test)
y_pred

# %%
a=r2_score(y_test, y_pred) 
print("Simple linear regression : ",a)

# %%
mean_squared_error(y_test, y_pred,squared=False)

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model1 = KNeighborsRegressor(n_neighbors=5)
model1.fit(X_train,y_train)

# %%
y_pred = model1.predict(X_test)
y_pred

# %%
b=r2_score(y_test, y_pred) 
print("KNN regressior : ",b)

# %%
mean_squared_error(y_test, y_pred)

# %%
mean_squared_error(y_test, y_pred,squared=False)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model1 = DecisionTreeRegressor()

# %%
model1.fit(X_train, y_train)

# %%
y_pred = model1.predict(X_test)

# %%
c=r2_score(y_test, y_pred) 
print("Decision Tree regression : ",c)

# %%
mean_squared_error(y_test, y_pred)

# %%
mean_squared_error(y_test, y_pred,squared=False)

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model1 = RandomForestRegressor(n_estimators = 100)

# %%
model1.fit(X_train,y_train)

# %%
y_pred = model1.predict(X_test)

# %%
y_pred_df = pd.DataFrame(y_pred)

# %%
d=r2_score(y_test, y_pred) 
print("Random forest regression : ",d)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)

# %%
mean_squared_error(y_test, y_pred,squared=False)

# %%
# Simple linear regrossion is best model for this data set

# %% [markdown]
# # saving the model

# %%
import joblib

# %%
joblib.dump(lr,"project1_model.pkl")
